# %%
from keras.datasets import mnist  
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np

np.random.seed(10)  
  
# Read MNIST data  
(X_train_M, y_train_M), (X_test_M, y_test_M) = mnist.load_data()  

X = np.concatenate((X_train_M, X_test_M))
y = np.concatenate((y_train_M, y_test_M))
# Out:
# /Users/wangfan/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Translation of data  
X_4D = X.reshape(X.shape[0], 28, 28, 1).astype('float32')  

# Standardize
X_4D_norm = X_4D/255

# Label Onehot-encoding 
y_Onehot = to_categorical(y)

# %%
X_train, X_test,y_train, y_test = train_test_split(X_4D_norm, y_Onehot, test_size=0.25, random_state=42)
np.save('/Users/wangfan/Documents/wukm/Uncertainty Projects/MNIST/X_test_MNIST.npy', X_test)
np.save('/Users/wangfan/Documents/wukm/Uncertainty Projects/MNIST/y_test_MNIST.npy', y_test)

# %%
from keras.models import Sequential  
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPool2D 
import keras
model = Sequential()  
# Create CN layer 1  
model.add(Conv2D(filters=16,  
                 kernel_size=(3,3),  
                 padding='same',  
                 input_shape=(28,28,1),  
                 activation='relu',
                 kernel_regularizer =keras.regularizers.l1(0.01),
                 name='conv2d_1')) 
# Create Max-Pool 1  
model.add(MaxPool2D(pool_size=(2,2), name='max_pooling2d_1'))  

# Add Dropout layer  
model.add(Dropout(0.5, name='dropout_1'))
  
# Create CN layer 2  
model.add(Conv2D(filters=36,  
                 kernel_size=(3,3),  
                 padding='same',  
                 input_shape=(28,28,1),  
                 activation='relu',
                 name='conv2d_2'))  
# Create Max-Pool 2  
model.add(MaxPool2D(pool_size=(2,2), name='max_pooling2d_2'))  
  
# Add Dropout layer  
model.add(Dropout(0.5, name='dropout_2'))
# Out:
# /Users/wangfan/Library/Python/3.9/lib/python/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(Flatten(name='flatten_1'))

# %%
model.add(Dense(128, activation='relu', name='dense_1'))  
model.add(Dropout(0.5, name='dropout_3'))

# %%
model.add(Dense(10, activation='softmax', name='dense_2'))

# %%
model.summary()  
print("")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 36)     │         5,220 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 7, 7, 36)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 7, 36)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1764)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │       225,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 232,590 (908.55 KB)
#  Trainable params: 232,590 (908.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.optimizers import SGD

callback = keras.callbacks.EarlyStopping(monitor='loss',patience=3)
# 定義訓練方式  
sgd = SGD(learning_rate = 0.001, momentum = 0.95)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])  
  
# 開始訓練  
train_history = model.fit(x=X_train,  
                          y=y_train, validation_split=0.2,  
                          epochs=100, batch_size=256, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.5626 - loss: 1.4167 - val_accuracy: 0.9373 - val_loss: 0.3421
# Epoch 2/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8841 - loss: 0.4640 - val_accuracy: 0.9597 - val_loss: 0.2372
# Epoch 3/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9141 - loss: 0.3528 - val_accuracy: 0.9678 - val_loss: 0.1903
# Epoch 4/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9283 - loss: 0.3043 - val_accuracy: 0.9710 - val_loss: 0.1660
# Epoch 5/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9351 - loss: 0.2749 - val_accuracy: 0.9727 - val_loss: 0.1522
# Epoch 6/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9386 - loss: 0.2525 - val_accuracy: 0.9753 - val_loss: 0.1380
# Epoch 7/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9432 - loss: 0.2323 - val_accuracy: 0.9768 - val_loss: 0.1266
# Epoch 8/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9462 - loss: 0.2195 - val_accuracy: 0.9771 - val_loss: 0.1216
# Epoch 9/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9499 - loss: 0.2044 - val_accuracy: 0.9790 - val_loss: 0.1128
# Epoch 10/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9514 - loss: 0.2011 - val_accuracy: 0.9783 - val_loss: 0.1097
# Epoch 11/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9555 - loss: 0.1833 - val_accuracy: 0.9784 - val_loss: 0.1079
# Epoch 12/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9557 - loss: 0.1829 - val_accuracy: 0.9802 - val_loss: 0.1002
# Epoch 13/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9562 - loss: 0.1767 - val_accuracy: 0.9803 - val_loss: 0.0995
# Epoch 14/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9565 - loss: 0.1712 - val_accuracy: 0.9804 - val_loss: 0.0936
# Epoch 15/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9590 - loss: 0.1664 - val_accuracy: 0.9810 - val_loss: 0.0926
# Epoch 16/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9622 - loss: 0.1576 - val_accuracy: 0.9812 - val_loss: 0.0886
# Epoch 17/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9615 - loss: 0.1538 - val_accuracy: 0.9826 - val_loss: 0.0872
# Epoch 18/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9635 - loss: 0.1519 - val_accuracy: 0.9826 - val_loss: 0.0856
# Epoch 19/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9638 - loss: 0.1489 - val_accuracy: 0.9828 - val_loss: 0.0836
# Epoch 20/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9653 - loss: 0.1416 - val_accuracy: 0.9835 - val_loss: 0.0830
# Epoch 21/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9659 - loss: 0.1399 - val_accuracy: 0.9841 - val_loss: 0.0792
# Epoch 22/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9666 - loss: 0.1378 - val_accuracy: 0.9826 - val_loss: 0.0794
# Epoch 23/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9665 - loss: 0.1391 - val_accuracy: 0.9836 - val_loss: 0.0771
# Epoch 24/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9666 - loss: 0.1314 - val_accuracy: 0.9843 - val_loss: 0.0760
# Epoch 25/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9668 - loss: 0.1317 - val_accuracy: 0.9839 - val_loss: 0.0769
# Epoch 26/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9682 - loss: 0.1255 - val_accuracy: 0.9844 - val_loss: 0.0739
# Epoch 27/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9684 - loss: 0.1259 - val_accuracy: 0.9849 - val_loss: 0.0731
# Epoch 28/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9677 - loss: 0.1248 - val_accuracy: 0.9846 - val_loss: 0.0705
# Epoch 29/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9682 - loss: 0.1239 - val_accuracy: 0.9851 - val_loss: 0.0697
# Epoch 30/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9719 - loss: 0.1136 - val_accuracy: 0.9852 - val_loss: 0.0693
# Epoch 31/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9692 - loss: 0.1195 - val_accuracy: 0.9860 - val_loss: 0.0677
# Epoch 32/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9701 - loss: 0.1192 - val_accuracy: 0.9858 - val_loss: 0.0680
# Epoch 33/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9716 - loss: 0.1159 - val_accuracy: 0.9864 - val_loss: 0.0655
# Epoch 34/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9704 - loss: 0.1165 - val_accuracy: 0.9852 - val_loss: 0.0664
# Epoch 35/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9717 - loss: 0.1130 - val_accuracy: 0.9861 - val_loss: 0.0646
# Epoch 36/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9693 - loss: 0.1224 - val_accuracy: 0.9860 - val_loss: 0.0659
# Epoch 37/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9711 - loss: 0.1127 - val_accuracy: 0.9865 - val_loss: 0.0634
# Epoch 38/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9718 - loss: 0.1084 - val_accuracy: 0.9863 - val_loss: 0.0629
# Epoch 39/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9741 - loss: 0.1034 - val_accuracy: 0.9869 - val_loss: 0.0623
# Epoch 40/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9734 - loss: 0.1069 - val_accuracy: 0.9863 - val_loss: 0.0620
# Epoch 41/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9724 - loss: 0.1075 - val_accuracy: 0.9875 - val_loss: 0.0614
# Epoch 42/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9743 - loss: 0.1007 - val_accuracy: 0.9867 - val_loss: 0.0599
# Epoch 43/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.9721 - loss: 0.1086 - val_accuracy: 0.9867 - val_loss: 0.0603
# Epoch 44/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9717 - loss: 0.1104 - val_accuracy: 0.9868 - val_loss: 0.0594
# Epoch 45/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9739 - loss: 0.1042 - val_accuracy: 0.9862 - val_loss: 0.0613

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.06162986159324646
# Test accuracy: 0.9864571690559387

# %%
import matplotlib.pyplot as plt
# Extract loss values
train_loss = train_history.history['loss']
val_loss = train_history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

# Plot the losses
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'bo-', label='Training Loss')
plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
plt.title('Training and Validation Loss per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 提取準確率數據
train_acc = train_history.history['accuracy']
val_acc = train_history.history['val_accuracy']
epochs = range(1, len(train_acc) + 1)

# 繪製準確率曲線
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_acc, 'bo-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
plt.title('Training and Validation Accuracy per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
model.save('/Users/wangfan/Documents/wukm/Uncertainty Projects/MNIST/MNIST.keras')
